# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Creando el ambiente
#
#
# MKDIR WORK1

# %% [markdown]
# - https://www.udemy.com/big-data-internship-program-part-1-foundation/learn/v4/t/lecture/5273654?start=0
