# %% [markdown]
# # Mediciones de desempeño
#
#  - Desempeño de Medición
#  - Desempeño del Monitoreo del Estado de Suministro
#  - Desempeño del Monitoreo de Calidad del Producto
#  - Desempeño del Control

# %% [markdown]
# # Arquitectura de los SMMC
#
# 1. Unidad de Medida.
# 2. Unidad Concentradora (opcional).
# 3. Sistemas de Gestión y Operación.
# 4. Almacén de reportes y datos.
# 5. Comunicaciones.
# 6. Seguridad.
# 7. Interfaces de interoperabilidad.
# 8. Sistema de Sincronización horaria.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### medida 1 : desempeño de medicion
#
# - cantidad de registros obtenidos de menera remota  / cantidad original que debiese estar en la bases de datos del sistema
#
#
# #### medida 2  :  Desemepño de monitoreo del estado de suministro
# -  notificaciones de desconeccion del servicio  / total de desconecciones del servicio
#
# periodo de 3 minutos en face de prueba resgistro de matriz de contingencia y posible mediciones externas por ROC .
#
# #### medida 3  : Desemepño del monitoreo de la calidada del prioducto
#
# -  N° de alarmas de calidad de producto remotas  / N° total de alarmas de calidad del producto
#
#
#
# #### media 4  : Desempeño del control
#
# - cantidad de eventos registrados  / total de eventos generados
